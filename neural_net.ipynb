# %%
# !pip install fastai
# Out:
# Collecting fastai
#   Downloading fastai-2.5.2-py3-none-any.whl (186 kB)
#      |████████████████████████████████| 186 kB 8.9 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /home/21rfk/.local/lib/python3.8/site-packages (from fastai) (1.7.1)
# Collecting spacy<4
#   Downloading spacy-3.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 20.8 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn in /home/21rfk/.local/lib/python3.8/site-packages (from fastai) (1.0)
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.5-py3-none-any.whl (13 kB)
# Collecting fastcore<1.4,>=1.3.8
#   Downloading fastcore-1.3.26-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 15.7 MB/s eta 0:00:01
# Requirement already satisfied: pillow>6.0.0 in /usr/lib/python3/dist-packages (from fastai) (7.0.0)
# Requirement already satisfied: pandas in /home/21rfk/.local/lib/python3.8/site-packages (from fastai) (1.3.4)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from fastai) (2.22.0)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from fastai) (5.3.1)
# Requirement already satisfied: pip in /usr/lib/python3/dist-packages (from fastai) (20.0.2)
# Requirement already satisfied: matplotlib in /home/21rfk/.local/lib/python3.8/site-packages (from fastai) (3.4.3)
# Collecting torch<1.10,>=1.7.0
#   Downloading torch-1.9.1-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      |████████████▋                   | 328.6 MB 119.9 MB/s eta 0:00:05   |█▊                              | 44.6 MB 20.5 MB/s eta 0:00:39     |████████▌                       | 222.3 MB 123.0 MB/s eta 0:00:05
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████                | 414.0 MB 119.9 MB/s eta 0:00:04
#      |████████████████▏               | 418.8 MB 119.9 MB/s eta 0:00:04
#      |████████████████▎               | 423.5 MB 93.4 MB/s eta 0:00:05
#      |████████████████▌               | 428.3 MB 93.4 MB/s eta 0:00:05
#      |████████████████▊               | 433.1 MB 93.4 MB/s eta 0:00:05
#      |████████████████▉               | 438.0 MB 93.4 MB/s eta 0:00:05
#      |█████████████████               | 442.9 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▎              | 447.6 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▍              | 451.1 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▍              | 452.4 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▌              | 453.9 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▌              | 455.8 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▋              | 457.4 MB 93.4 MB/s eta 0:00:05
#      |█████████████████▊              | 459.1 MB 93.4 MB/s eta 0:00:04
ylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 19.3 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 61.9 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<4->fastai) (45.2.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai) (4.62.3)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/21rfk/.local/lib/python3.8/site-packages (from scikit-learn->fastai) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /home/21rfk/.local/lib/python3.8/site-packages (from scikit-learn->fastai) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas->fastai) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas->fastai) (2.7.3)
# Requirement already satisfied: cycler>=0.10 in /home/21rfk/.local/lib/python3.8/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/21rfk/.local/lib/python3.8/site-packages (from matplotlib->fastai) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->fastai) (2.4.7)
# Collecting typing-extensions
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting click<9.0.0,>=7.1.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 15.4 MB/s eta 0:00:01
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 25.4 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<4->fastai) (1.1.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib->fastai) (1.14.0)
# ERROR: torchvision 0.11.1 has requirement torch==1.10.0, but you'll have torch 1.9.1 which is incompatible.
# Installing collected packages: cymem, murmurhash, preshed, click, typer, catalogue, srsly, wasabi, blis, typing-extensions, pydantic, thinc, smart-open, pathy, spacy-legacy, spacy, fastprogress, fastcore, fastdownload, torch, torchvision, fastai
# Successfully installed blis-0.7.4 catalogue-2.0.6 click-8.0.3 cymem-2.0.5 fastai-2.5.2 fastcore-1.3.26 fastdownload-0.0.5 fastprogress-1.0.0 murmurhash-1.0.5 pathy-0.6.0 preshed-3.0.5 pydantic-1.8.2 smart-open-5.2.1 spacy-3.1.3 spacy-legacy-3.0.8 srsly-2.4.1 thinc-8.0.11 torch-1.9.1 torchvision-0.11.1 typer-0.4.0 typing-extensions-3.10.0.2 wasabi-0.8.2

# %%
import pandas as pd

# %%
faces = pd.read_csv('faces_smaller_chunk.csv')
vgg = pd.read_csv('./vgg_chunks/chunk_1.csv', index_col=0, header=0)

# %%
from fastai.tabular.all import *
# Out:
# /home/21rfk/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 803: system has unsupported display driver / cuda driver combination (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   return torch._C._cuda_getDeviceCount() > 0
